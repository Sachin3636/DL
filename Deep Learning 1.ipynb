# %%
import pandas as pd

# %%
df=pd.read_csv("Boston.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
x=df.iloc[:,0:13]
y=df.iloc[:,-1]

# %%
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

mms.fit(x_train)
x_train=mms.transform(x_train)
x_test=mms.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

model.add(Dense(128, activation='relu', name='Input'))
model.add(Dense(64,activation='relu', name='hidden'))
model.add(Dense(1,activation='linear', name='dense_output'))

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ Input (Dense)                        │ (None, 128)                 │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ hidden (Dense)                       │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_output (Dense)                 │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,113 (39.50 KB)
#  Trainable params: 10,113 (39.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, epochs=10, validation_split=0.05, verbose = 1)
# Out:
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 32.3987 - mae: 3.8696 - val_loss: 19.9207 - val_mae: 3.1500
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.5654 - mae: 3.7070 - val_loss: 18.9199 - val_mae: 3.1412
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.2456 - mae: 3.5233 - val_loss: 18.4735 - val_mae: 3.1057
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.5004 - mae: 3.3367 - val_loss: 15.7923 - val_mae: 2.9694
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.2747 - mae: 3.3239 - val_loss: 16.2404 - val_mae: 2.9982
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.8315 - mae: 3.2122 - val_loss: 15.2988 - val_mae: 2.9782
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.8473 - mae: 3.3094 - val_loss: 15.2534 - val_mae: 2.9532
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.0918 - mae: 3.1840 - val_loss: 14.4014 - val_mae: 2.9956
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.6650 - mae: 3.0778 - val_loss: 14.7326 - val_mae: 2.9977
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.2999 - mae: 2.9423 - val_loss: 14.2190 - val_mae: 2.9993

# %%
y_pred=model.predict(x_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
y_pred
# Out:
# array([[20.74763  ],
#        [14.412445 ],
#        [24.138786 ],
#        [28.167442 ],
#        [29.050798 ],
#        [27.83594  ],
#        [34.330685 ],
#        [20.220417 ],
#        [18.616514 ],
#        [22.501312 ],
#        [17.403246 ],
#        [19.563286 ],
#        [25.234236 ],
#        [26.957582 ],
#        [17.066961 ],
#        [14.653261 ],
#        [21.298811 ],
#        [33.140682 ],
#        [17.811918 ],
#        [ 7.1652265],
#        [25.829721 ],
#        [13.220657 ],
#        [17.117575 ],
#        [32.78274  ],
#        [36.95897  ],
#        [24.896612 ],
#        [11.093413 ],
#        [23.246473 ],
#        [21.672356 ],
#        [35.04449  ],
#        [17.59278  ],
#        [22.956383 ],
#        [16.009308 ],
#        [39.44633  ],
#        [17.12375  ],
#        [38.038483 ],
#        [22.826723 ],
#        [21.632439 ],
#        [22.586992 ],
#        [13.433134 ],
#        [27.972958 ],
#        [24.065268 ],
#        [11.411337 ],
#        [23.18593  ],
#        [14.820722 ],
#        [29.339159 ],
#        [25.761938 ],
#        [19.897135 ],
#        [18.622051 ],
#        [19.473682 ],
#        [ 9.206583 ],
#        [30.387821 ],
#        [22.760618 ],
#        [39.043266 ],
#        [19.557583 ],
#        [20.565187 ],
#        [29.525858 ],
#        [27.88038  ],
#        [18.210136 ],
#        [28.005323 ],
#        [22.960112 ],
#        [24.471523 ],
#        [19.189997 ],
#        [36.876423 ],
#        [19.993866 ],
#        [21.084787 ],
#        [31.895182 ],
#        [13.050776 ],
#        [20.5252   ],
#        [20.409657 ],
#        [23.99143  ],
#        [17.091745 ],
#        [36.710613 ],
#        [18.145803 ],
#        [11.663084 ],
#        [20.583984 ],
#        [11.939199 ],
#        [20.205423 ],
#        [29.56792  ],
#        [27.496218 ],
#        [36.062782 ],
#        [16.977362 ],
#        [26.090036 ],
#        [18.83478  ],
#        [24.647245 ],
#        [20.8575   ],
#        [24.437273 ],
#        [35.01042  ],
#        [17.184103 ],
#        [25.56341  ],
#        [19.446602 ],
#        [20.572924 ],
#        [30.771046 ],
#        [18.405373 ],
#        [14.645291 ],
#        [14.263162 ],
#        [26.407852 ],
#        [21.208311 ],
#        [10.9840765],
#        [18.439444 ],
#        [13.3228655],
#        [21.076643 ],
#        [12.912221 ],
#        [18.398506 ],
#        [32.85884  ],
#        [23.045214 ],
#        [24.638464 ],
#        [24.40995  ],
#        [20.288319 ],
#        [25.373293 ],
#        [ 9.679098 ],
#        [26.367266 ],
#        [28.641386 ],
#        [10.587765 ],
#        [24.095968 ],
#        [20.390865 ],
#        [33.17295  ],
#        [19.870913 ],
#        [21.385218 ],
#        [25.386614 ],
#        [23.882734 ],
#        [35.03588  ],
#        [26.866877 ],
#        [20.976492 ],
#        [27.801123 ],
#        [33.68018  ],
#        [ 3.8741915],
#        [12.84575  ],
#        [28.182632 ],
#        [20.643911 ],
#        [13.687794 ],
#        [10.885381 ],
#        [25.110113 ],
#        [30.1804   ],
#        [12.962265 ],
#        [20.264294 ],
#        [35.44068  ],
#        [28.052889 ],
#        [26.91857  ],
#        [38.824238 ],
#        [30.919714 ],
#        [31.889307 ],
#        [20.46145  ],
#        [35.34671  ],
#        [21.641968 ],
#        [19.799862 ],
#        [11.563314 ],
#        [17.326733 ],
#        [14.305872 ],
#        [ 9.233292 ],
#        [10.685285 ],
#        [24.57937  ]], dtype=float32)
